# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
content= pd.read_csv("Content.csv")
location= pd.read_csv("Location.csv")
profile= pd.read_csv("Profile.csv")
reactions= pd.read_csv("Reactions.csv")
reactionTypes= pd.read_csv("ReactionTypes.csv")
session= pd.read_csv("Session.csv")
user= pd.read_csv("User.csv")

# %%
content.shape
# Out:
# (1000, 6)

# %%
content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
content.drop("Unnamed: 0", axis=1, inplace=True)

# %%
content.isnull().sum()
# Out:
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
content["Category"].value_counts(normalize=True)
# Out:
# technology           0.071
# animals              0.067
# travel               0.067
# culture              0.063
# science              0.063
# fitness              0.061
# food                 0.061
# healthy eating       0.061
# cooking              0.060
# soccer               0.058
# tennis               0.058
# education            0.057
# dogs                 0.056
# studying             0.055
# veganism             0.048
# public speaking      0.048
# Fitness              0.005
# Animals              0.004
# Science              0.004
# "soccer"             0.003
# "culture"            0.003
# Soccer               0.003
# "dogs"               0.002
# Education            0.002
# Studying             0.002
# Travel               0.002
# Food                 0.002
# "veganism"           0.001
# "public speaking"    0.001
# Public Speaking      0.001
# "technology"         0.001
# "cooking"            0.001
# Healthy Eating       0.001
# "studying"           0.001
# ...

# %%
location.shape
# Out:
# (500, 3)

# %%
location.head()
# Out:
#    Unnamed: 0                               User ID  \
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
#
#                                              Address
# 0        6208 Wright Mountains\nBryantfurt, AR 02531
# 1  534 Williams Turnpike Suite 788\nPort Julie, W...
# 2  867 Lisa Causeway Apt. 015\nWest Brentmouth, A...
# 3  5687 Wilson Harbors Suite 763\nLake Robert, FL...
# 4                   Unit 2614 Box 8996\nDPO AE 23660

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Address     500 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.8+ KB

# %%
location.drop("Unnamed: 0", axis=1, inplace=True)

# %%
location.isnull().sum()
# Out:
# User ID    0
# Address    0
# dtype: int64

# %%
profile.shape
# Out:
# (500, 4)

# %%
profile.head()
# Out:
#    Unnamed: 0                               User ID  \
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
#
#                                      Interests  Age
# 0                                       [0, 1]   41
# 1                                   ['tennis']   23
# 2  ['fitness', 'cooking', 'animals', 'travel']   25
# 3        ['technology', 'culture', 'veganism']    2
# 4                                ['education']   44

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Interests   500 non-null    object
#  3   Age         500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
profile.drop("Unnamed: 0", axis=1, inplace=True)

# %%
profile.isnull().sum()
# Out:
# User ID      0
# Interests    0
# Age          0
# dtype: int64

# %%
reactions.shape
# Out:
# (25553, 5)

# %%
reactions.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
reactions.drop("Unnamed: 0", axis=1, inplace=True)

# %%
reactions.isnull().sum()
# Out:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
reactionTypes.shape
# Out:
# (16, 4)

# %%
reactionTypes.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
reactionTypes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
reactionTypes.drop("Unnamed: 0", axis=1, inplace=True)

# %%
session.shape
# Out:
# (500, 4)

# %%
session.head()
# Out:
#    Unnamed: 0                               User ID     Device  Duration
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Microsoft        11
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5      Apple        51
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb        HTC        25
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb   Motorola        68
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9     Huawei        57

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Device      500 non-null    object
#  3   Duration    500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
session.drop("Unnamed: 0", axis=1, inplace=True)

# %%
user.shape
# Out:
# (500, 4)

# %%
user.head()
# Out:
#    Unnamed: 0                               User ID             Name  \
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8        Gary Hill
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5  Michael Deering
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb     Richard Bain
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb  Kristi Mccarthy
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9      Betty Ellis
#
#           Email
# 0  GHbnuothhymw
# 1  MD@gmail.com
# 2  RB@gmail.com
# 3  KM@gmail.com
# 4  BE@gmail.com

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Name        500 non-null    object
#  3   Email       500 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.8+ KB

# %%
user.drop("Unnamed: 0", axis=1, inplace=True)

# %%
user.isnull().sum()
# Out:
# User ID    0
# Name       0
# Email      0
# dtype: int64

# %%
df1 = user.merge(location, on= 'User ID').merge(session, on ='User ID').merge(profile, on="User ID").merge(content, on="User ID")
df1
# Out:
#                                   User ID               Name         Email  \
# 0    4c731e48-0377-4d7d-b4c8-b2174b774ed8          Gary Hill  GHbnuothhymw
# 1    4c731e48-0377-4d7d-b4c8-b2174b774ed8          Gary Hill  GHbnuothhymw
# 2    4c731e48-0377-4d7d-b4c8-b2174b774ed8          Gary Hill  GHbnuothhymw
# 3    95258c36-5b6b-4591-85ee-0c43f503c1d5    Michael Deering  MD@gmail.com
# 4    95258c36-5b6b-4591-85ee-0c43f503c1d5    Michael Deering  MD@gmail.com
# ..                                    ...                ...           ...
# 995  0d47a133-383b-4a9c-976c-697ac65ccb19  Jennifer Mcintosh  JM@gmail.com
# 996  db0066e1-83cc-43f3-990b-983010aa5370   Marion Stecklein  MS@gmail.com
# 997  db0066e1-83cc-43f3-990b-983010aa5370   Marion Stecklein  MS@gmail.com
# 998  d6204684-926d-41db-ae9c-a7bf2e76313a      Jeffery Zerbe  JZ@gmail.com
# 999  07f4dcd0-2bf3-4f21-9da3-b054b511ae00       Darcel Smith  DS@gmail.com
#
# ...

# %%
df1.isnull().sum()
# Out:
# User ID         0
# Name            0
# Email           0
# Address         0
# Device          0
# Duration        0
# Interests       0
# Age             0
# Content ID      0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
df1.rename(columns = {'Type':'Content_Type'}, inplace = True)

# %%
df1.head()
# Out:
#                                 User ID             Name         Email  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8        Gary Hill  GHbnuothhymw
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8        Gary Hill  GHbnuothhymw
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8        Gary Hill  GHbnuothhymw
# 3  95258c36-5b6b-4591-85ee-0c43f503c1d5  Michael Deering  MD@gmail.com
# 4  95258c36-5b6b-4591-85ee-0c43f503c1d5  Michael Deering  MD@gmail.com
#
#                                              Address     Device  Duration  \
# 0        6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11
# 1        6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11
# 2        6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11
# 3  534 Williams Turnpike Suite 788\nPort Julie, W...      Apple        51
# 4  534 Williams Turnpike Suite 788\nPort Julie, W...      Apple        51
#
#     Interests  Age                            Content ID Content_Type  \
# ...

# %%
df2 = reactions.merge(reactionTypes, on = "Type")
df2
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f
# ...                                     ...
# 24568  435007a5-6261-4d8b-b0a4-55fdc189754b
# 24569  435007a5-6261-4d8b-b0a4-55fdc189754b
# 24570  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 24571  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 24572  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
#
#                                     User ID     Type             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 1      34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01
# 2      13c06e7e-833d-47eb-a790-5e09ccfd8d2c  disgust  2021-04-09 02:46:20
# 3      8b49caad-bcc5-43de-bf40-34a66ff8805c  disgust  2021-03-28 21:15:26
# ...

# %%
df2.isnull().sum()
# Out:
# Content ID       0
# User ID       2039
# Type             0
# Datetime         0
# Sentiment        0
# Score            0
# dtype: int64

# %%
df3 = df1.merge(df2, on = "Content ID")
df3.head()
# Out:
#                               User ID_x       Name         Email  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 3  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 4  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
#
#                                        Address     Device  Duration Interests  \
# 0  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 1  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 2  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 3  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 4  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
#
#    Age                            Content ID Content_Type Category  \
# ...

# %%
df3.isnull().mean()
# Out:
# User ID_x       0.000000
# Name            0.000000
# Email           0.000000
# Address         0.000000
# Device          0.000000
# Duration        0.000000
# Interests       0.000000
# Age             0.000000
# Content ID      0.000000
# Content_Type    0.000000
# Category        0.000000
# URL             0.183820
# User ID_y       0.082977
# Type            0.000000
# Datetime        0.000000
# Sentiment       0.000000
# Score           0.000000
# dtype: float64

# %%
df3.head()
# Out:
#                               User ID_x       Name         Email  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 3  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
# 4  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Gary Hill  GHbnuothhymw
#
#                                        Address     Device  Duration Interests  \
# 0  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 1  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 2  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 3  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
# 4  6208 Wright Mountains\nBryantfurt, AR 02531  Microsoft        11    [0, 1]
#
#    Age                            Content ID Content_Type Category  \
# ...

# %%
df3.isnull().sum()
# Out:
# User ID_x          0
# Name               0
# Email              0
# Address            0
# Device             0
# Duration           0
# Interests          0
# Age                0
# Content ID         0
# Content_Type       0
# Category           0
# URL             4517
# User ID_y       2039
# Type               0
# Datetime           0
# Sentiment          0
# Score              0
# dtype: int64

# %%
df3.drop(columns=["Name", "Email", "Address", "Device", "URL"], inplace=True)

# %%
df3.drop(columns=["Age", "Duration"],  inplace=True)

# %%
df3.drop(columns=["User ID_y", "Interests"],  inplace=True)

# %%
df3
# Out:
#                                   User ID_x  \
# 0      4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1      4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 2      4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 3      4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 4      4c731e48-0377-4d7d-b4c8-b2174b774ed8
# ...                                     ...
# 24568  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
# 24569  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
# 24570  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
# 24571  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
# 24572  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                  Content ID Content_Type Category  \
# 0      636e6499-b670-4cd4-a829-2c4c9e07db2a        photo   soccer
# 1      636e6499-b670-4cd4-a829-2c4c9e07db2a        photo   soccer
# 2      636e6499-b670-4cd4-a829-2c4c9e07db2a        photo   soccer
# 3      636e6499-b670-4cd4-a829-2c4c9e07db2a        photo   soccer
# 4      636e6499-b670-4cd4-a829-2c4c9e07db2a        photo   soccer
# ...

# %%
df3.rename(columns = {'Type':'Reaction_Type'}, inplace = True)

# %%
df3.head()
# Out:
#                               User ID_x                            Content ID  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 3  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 4  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
#
#   Content_Type Category Reaction_Type             Datetime Sentiment  Score
# 0        photo   soccer       disgust  2020-10-25 11:46:47  negative      0
# 1        photo   soccer       dislike  2021-01-07 12:59:27  negative     10
# 2        photo   soccer       cherish  2020-08-21 11:58:23  positive     70
# 3        photo   soccer          love  2020-07-23 00:40:06  positive     65
# 4        photo   soccer   indifferent  2020-12-31 20:12:39   neutral     20

# %%
df3.rename(columns = {'User ID_x':'User ID'}, inplace = True)

# %%
df3.head()
# Out:
#                                 User ID                            Content ID  \
# 0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 1  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 2  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 3  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
# 4  4c731e48-0377-4d7d-b4c8-b2174b774ed8  636e6499-b670-4cd4-a829-2c4c9e07db2a
#
#   Content_Type Category Reaction_Type             Datetime Sentiment  Score
# 0        photo   soccer       disgust  2020-10-25 11:46:47  negative      0
# 1        photo   soccer       dislike  2021-01-07 12:59:27  negative     10
# 2        photo   soccer       cherish  2020-08-21 11:58:23  positive     70
# 3        photo   soccer          love  2020-07-23 00:40:06  positive     65
# 4        photo   soccer   indifferent  2020-12-31 20:12:39   neutral     20

# %%
df3.to_csv("Final_Dataset")

# %%
df_final = df2.merge(content, on= "Content ID")
df_final.head()
# Out:
#                              Content ID                             User ID_x  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  13c06e7e-833d-47eb-a790-5e09ccfd8d2c
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  69532ce2-1ffe-4187-8042-0230d115b24e
#
#     Type_x             Datetime Sentiment  Score  \
# 0  disgust  2020-11-07 09:43:50  negative      0
# 1  disgust  2021-01-06 19:13:01  negative      0
# 2  disgust  2021-04-09 02:46:20  negative      0
# 3  dislike  2021-06-17 12:22:51  negative     10
# 4  dislike  2020-11-09 02:49:59  negative     10
#
#                               User ID_y Type_y  Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# ...

# %%
df_final.drop(columns=["User ID_x", "URL"],  inplace=True)

# %%
df_final.rename(columns = {'User ID_y':'User ID'}, inplace = True)

# %%
df_final.rename(columns = {'Type_x':'Reaction_Type'}, inplace = True)

# %%
df_final.rename(columns = {'Type_y':'Content_Type'}, inplace = True)

# %%
df_final.head()
# Out:
#                              Content ID Reaction_Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-04-09 02:46:20
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2020-11-09 02:49:59
#
#   Sentiment  Score                               User ID Content_Type  \
# 0  negative      0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1  negative      0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 2  negative      0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 3  negative     10  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 4  negative     10  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
#
#    Category
# 0  Studying
# 1  Studying
# 2  Studying
# 3  Studying
# 4  Studying

# %%
# rearrange columns
cols = list(df_final.columns)
cols = cols[0:3] + cols[5:8] + cols[3:5]
df = df_final[cols]
df
# Out:
#                                  Content ID Reaction_Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# ...                                     ...           ...
# 24568  99fcc8a6-550f-47a1-b312-aba8a031f6c7         heart
# 24569  004e820e-49c3-4ba2-9d02-62db0065410c         heart
# 24570  a7849ef3-5930-4ba9-9cbe-e215811e713e         heart
# 24571  e5f1a4c6-2b27-4c8b-ac9a-21bb6ef7c946          want
# 24572  c59e27e9-0439-4699-8ea0-5e93f662a05d         adore
#
#                   Datetime                               User ID Content_Type  \
# 0      2020-11-07 09:43:50  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1      2021-01-06 19:13:01  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# ...

# %%
df.to_csv("Final_Submission")

# %%
df.head()
# Out:
#                              Content ID Reaction_Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-04-09 02:46:20
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2020-11-09 02:49:59
#
#                                 User ID Content_Type  Category Sentiment  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
#
#    Score
# 0      0
# 1      0
# 2      0
# 3     10
# 4     10

# %%
# Year and month column
df['year'] = pd.DatetimeIndex(df['Datetime']).year
df['month'] = pd.DatetimeIndex(df['Datetime']).month
df["day"] = pd.DatetimeIndex(df["Datetime"]).day
# Out:
# C:\Users\Taimoor Razi\AppData\Local\Temp\ipykernel_17228\3664827127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.DatetimeIndex(df['Datetime']).year
# C:\Users\Taimoor Razi\AppData\Local\Temp\ipykernel_17228\3664827127.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = pd.DatetimeIndex(df['Datetime']).month
# C:\Users\Taimoor Razi\AppData\Local\Temp\ipykernel_17228\3664827127.py:4: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#                              Content ID Reaction_Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-04-09 02:46:20
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2020-11-09 02:49:59
#
#                                 User ID Content_Type  Category Sentiment  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
#
#    Score  year  month  day
# 0      0  2020     11    7
# ...

# %%
mad=df.groupby(['month'])['Content ID'].agg(['count'])
mad=mad.reset_index(level='month', col_level=1)
mad = mad.sort_values(by='month', ascending= True )

# %%
g=sns.catplot('month','count',data=mad,kind='bar',palette = 'rocket', height=8.27, aspect=11.7/8.27)

ax = g.facet_axis(0,0)
for p in ax.patches:
    ax.text(p.get_x() + 0.015, 
            p.get_height() * 1.02, 
            "{:.0f}".format(p.get_height()), 
            color='black', rotation='horizontal', size='medium')
plt.title('Monthly average demand by each Compny',fontsize=20)
plt.ylabel('Demand')
plt.xlabel('Month')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
mad=df.groupby(['Category'])['Content ID'].agg(['count'])
mad=mad.reset_index(level='Category', col_level=1)
mad = mad.sort_values(by='count', ascending= False )

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_categories = df.groupby("Category")["Score"].sum().sort_values(ascending=False)
top_categories
# Out:
# Category
# animals              69548
# healthy eating       69067
# technology           67472
# science              66043
# cooking              63982
# travel               63788
# food                 63122
# culture              62915
# education            56041
# soccer               52684
# studying             52382
# dogs                 50748
# tennis               50339
# fitness              49835
# veganism             47846
# public speaking      46949
# Fitness               5488
# Science               4619
# Animals               3723
# Food                  3504
# Soccer                2631
# "soccer"              2468
# "culture"             2037
# "dogs"                1763
# "animals"             1694
# Culture               1627
# Education             1395
# Studying              1341
# Public Speaking       1336
# "veganism"            1129
# Travel                1092
# "technology"          1049
# "public speaking"      979
# "cooking"              774
# ...

# %%
top_categories.to_csv("Top_categories")

# %%
df.shape
# Out:
# (24573, 11)
